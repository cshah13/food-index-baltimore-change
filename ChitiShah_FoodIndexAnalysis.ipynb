# %% [markdown]
# <a href="https://colab.research.google.com/github/cshah13/food-index-baltimore-change/blob/main/ChitiShah_FoodIndexAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
# import libraries

# data analysis
import pandas as pd

# data visualization
import matplotlib.pyplot as plt
import plotly.express as px

# download files to our computer
from google.colab import files

# %% [markdown]
# # Import Data for Healthy Food Quality Index

# %% [markdown]
# Imported data from [this github here](https://github.com/cshah13/food-index-baltimore-change)

# %%
# import csv of healthy food quality index data

# save github csv link
index_data = "https://raw.githubusercontent.com/cshah13/food-index-baltimore-change/main/HFAI%20Python%20Data.csv"

#define our initial dataframe
df_index = pd.read_csv(index_data)

# %% [markdown]
# # Look at out data

# %%
# preview the first five rows
df_index.head()
# Out:
#                              CSA2010     hfai12     hfai15
# 0      Allendale/Irvington/S. Hilton   7.750000   7.526316
# 1    Beechfield/Ten Hills/West Hills  15.583333  10.400000
# 2                      Belair-Edison  10.326087   8.227273
# 3  Brooklyn/Curtis Bay/Hawkins Point   8.588235   8.793103
# 4                             Canton  16.900000  15.200000

# %%
df_index = df_index.rename(columns = {"CSA2010" : "Location", "hfai12" : "HFAI 2012", "hfai15" : "HFAI 2015"})

# %%
# plot indexes for 2012 and 2015 in a double line graph
plot = df_index.plot(x = "Location", y = ['HFAI 2012', 'HFAI 2015'], kind = "line", title = "Healthy Food Index Scores in Baltimore, MD in 2012 and 2015", figsize = (17,8))

plt.xlabel("Areas in Baltimore")
plt.ylabel("Healthy Food Availability Index Score")
# Out:
# Text(0, 0.5, 'Healthy Food Availability Index Score')

# %%
# plot indexes for 2012 and 2015 in a double line graph
plot = df_index.plot(x = "Location", y = ['HFAI 2012', 'HFAI 2015'], kind = "bar", title = "Healthy Food Index Scores in Baltimore, MD in 2012 and 2015", figsize = (15,8))

plt.xlabel("Areas in Baltimore")
plt.ylabel("Healthy Food Availability Index Score")
# Out:
# Text(0, 0.5, 'Healthy Food Availability Index Score')

# %%
# make double bar graph
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import plotly.graph_objects as px
import numpy as np

np.random.seed(56)  


random_x= np.random.randint(1,101,100) 
random_y= np.random.randint(1,101,100)
  
x = df_index['Location']
  
plot = px.Figure(data=[go.Bar(name = 'HFAI 2012', 
                              x = df_index['Location'],
                              y = df_index['HFAI 2012']),
                       go.Bar(name = 'HFAI 2015', x = df_index['Location'],y = df_index['HFAI 2015'])])

plot.update_layout(title="Health Food Availability Index in Baltimore, MD: 2012 and 2015", xaxis_title="Locations",
                   yaxis_title="Healthy Food Availability Index", width=1000, height=600)

plot.update_xaxes(categoryorder="total ascending")
plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4a1c0e6a-1609-4352-8c2b-06b839a04c96" class="plotly-graph-div" style="height:600px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a1c0e6a-1609-4352-8c2b-06b839a04c96")) {
#                     Plotly.newPlot(
#                         '4a1c0e6a-1609-4352-8c2b-06b839a04c96',
#                         [{"name": "HFAI 2012", "type": "bar", "x": ["Allendale/Irvington/S. Hilton", "Beechfield/Ten Hills/West Hills", "Belair-Edison", "Brooklyn/Curtis Bay/Hawkins Point", "Canton", "Cedonia/Frankford", "Cherry Hill", "Chinquapin Park/Belvedere", "Claremont/Armistead", "Clifton-Berea", "Dorchester/Ashburton", "Downtown/Seton Hill", "Edmondson Village", "Fells Point", "Forest Park/Walbrook", "Glen-Fallstaff", "Greater Charles Village/Barclay", "Greater Govans", "Greater Mondawmin", "Greater Roland Park/Poplar Hill", "Greater Rosemont", "Greenmount East", "Hamilton", "Harbor East/Little Italy", "Harford/Echodale", "Highlandtown", "Howard Park/West Arlington", "Inner Harbor/Federal Hill", "Lauraville", "Loch Raven", "Madison/East End", "Medfield/Hampden/Woodberry/Remington", "Midtown", "Midway/Coldstream", "Morrell Park/Violetville", "Mount Washington/Coldspring", "North Baltimore/Guilford/Homeland", "Northwood", "Oldtown/Middle East", "Orangeville/East Highlandtown", "Patterson Park North & East", "Penn North/Reservoir Hill", "Pimlico/Arlington/Hilltop", "Poppleton/The Terraces/Hollins Market", "Sandtown-Winchester/Harlem Park", "South Baltimore", "Southeastern", "Southern Park Heights", "Southwest Baltimore", "The Waverlies", "Upton/Druid Heights", "Washington Village/Pigtown", "Westport/Mount Winans/Lakeland"], "y": [7.75, 15.58333333, 10.32608696, 8.58823529, 16.9, 12.33333333, 8.78571429, 15.25, 7.35, 8.78125, 9.95833333, 6.70588235, 6.42857143, 10.2, 7.83333333, 10.29310345, 15.32608696, 8.90909091, 13.95454545, 11.75, 6.86764706, 9.575, 8.84375, 11.76923077, 9.91666667, 13.93333333, 10.2, 12.42857143, 11.5, 15.3125, 10.08695652, 10.425, 13.0, 8.02272727, 10.4375, 24.75, 7.52941176, 8.85714286, 8.39285714, 8.61904762, 12.65, 7.0, 9.75, 8.45454545, 9.39393939, 18.08333333, 7.16666667, 11.72222222, 10.26530612, 15.1, 9.80555556, 9.80555556, 14.36666667]}, {"name": "HFAI 2015", "type": "bar", "x": ["Allendale/Irvington/S. Hilton", "Beechfield/Ten Hills/West Hills", "Belair-Edison", "Brooklyn/Curtis Bay/Hawkins Point", "Canton", "Cedonia/Frankford", "Cherry Hill", "Chinquapin Park/Belvedere", "Claremont/Armistead", "Clifton-Berea", "Dorchester/Ashburton", "Downtown/Seton Hill", "Edmondson Village", "Fells Point", "Forest Park/Walbrook", "Glen-Fallstaff", "Greater Charles Village/Barclay", "Greater Govans", "Greater Mondawmin", "Greater Roland Park/Poplar Hill", "Greater Rosemont", "Greenmount East", "Hamilton", "Harbor East/Little Italy", "Harford/Echodale", "Highlandtown", "Howard Park/West Arlington", "Inner Harbor/Federal Hill", "Lauraville", "Loch Raven", "Madison/East End", "Medfield/Hampden/Woodberry/Remington", "Midtown", "Midway/Coldstream", "Morrell Park/Violetville", "Mount Washington/Coldspring", "North Baltimore/Guilford/Homeland", "Northwood", "Oldtown/Middle East", "Orangeville/East Highlandtown", "Patterson Park North & East", "Penn North/Reservoir Hill", "Pimlico/Arlington/Hilltop", "Poppleton/The Terraces/Hollins Market", "Sandtown-Winchester/Harlem Park", "South Baltimore", "Southeastern", "Southern Park Heights", "Southwest Baltimore", "The Waverlies", "Upton/Druid Heights", "Washington Village/Pigtown", "Westport/Mount Winans/Lakeland"], "y": [7.526315789, 10.4, 8.227272727, 8.793103448, 15.2, 8.956521739, 7.875, 8.666666667000001, 6.545454545, 8.15, 7.733333332999999, 8.931818182, 7.166666667, 11.25, 9.9375, 9.145833332999999, 10.87931034, 9.666666667000001, 9.730769231, 8.214285713999999, 7.512820512999999, 10.18421053, 7.961538462, 10.39285714, 8.653846154, 13.88888889, 9.076923077, 8.5, 9.25, 10.5, 9.711538462, 9.727272727, 11.17391304, 9.145833332999999, 9.136363636, 28.5, 8.0, 9.142857142999999, 8.884615385, 8.944444444, 10.8, 7.733333332999999, 7.97826087, 10.66666667, 9.14, 14.0, 12.31818182, 10.3, 8.921052632, 10.8, 8.45, 9.0, 11.33333333]}],
#                         {"height": 600, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "s
